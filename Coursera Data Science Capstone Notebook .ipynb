# %%
import requests
import pandas as pd
import numpy as np
import random

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim

from IPython.display import Image 
from IPython.core.display import HTML 

from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geopy-1.21.0               |             py_0          58 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     certifi-2019.11.28         |           py36_0         149 KB  conda-forge
#     openssl-1.1.1d             |       h516909a_0         2.1 MB  conda-forge
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.50-py_0         conda-forge
#     geopy:           1.21.0-py_0       conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.11.27-0                  --> 2019.11.28-hecc5488_0 conda-forge
#     certifi:         2019.11.28-py36_0             --> 2019.11.28-py36_0     conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.1.1d-h7b6447c_3             --> 1.1.1d-h516909a_0     conda-forge
#
#
# Downloading and Extracting Packages
# geopy-1.21.0         | 58 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# certifi-2019.11.28   | 149 KB    | ##################################### | 100%
# openssl-1.1.1d       | 2.1 MB    | ##################################### | 100%
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.0.1               |             py_0         575 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     branca-0.4.0               |             py_0          26 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         673 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  4.0.1-py_0 conda-forge
#     branca:  0.4.0-py_0 conda-forge
#     folium:  0.5.0-py_0 conda-forge
#     vincent: 0.4.4-py_1 conda-forge
#
#
# Downloading and Extracting Packages
# altair-4.0.1         | 575 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# branca-0.4.0         | 26 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'G3DDAPR0UTRHTRNCHGGIJSBHLA0FRGQ1UCPELALLXG34MLZL'
CLIENT_SECRET = 'KP4311DRJ350XDHABGWNO1PQMCI1JQXV1HYVBV3BJ2FYY1YA'
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: G3DDAPR0UTRHTRNCHGGIJSBHLA0FRGQ1UCPELALLXG34MLZL
# CLIENT_SECRET:KP4311DRJ350XDHABGWNO1PQMCI1JQXV1HYVBV3BJ2FYY1YA

# %%
latitude = 34.060
longitude = -84.357

# %%
search_query = 'Seafood'
radius = 7500
print(search_query + ' .... OK!')
# Out:
# Seafood .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=G3DDAPR0UTRHTRNCHGGIJSBHLA0FRGQ1UCPELALLXG34MLZL&client_secret=KP4311DRJ350XDHABGWNO1PQMCI1JQXV1HYVBV3BJ2FYY1YA&ll=34.06,-84.357&v=20180604&query=Seafood&radius=7500&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e51b14529ce6a001b303124'},
#  'response': {'venues': [{'id': '4a8864b0f964a520310620e3',
#     'name': 'Pappadeaux Seafood Kitchen',
#     'location': {'address': '10795 Davis Dr',
#      'lat': 34.04173,
#      'lng': -84.31159,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.04173,
#        'lng': -84.31159}],
#      'distance': 4655,
#      'postalCode': '30009',
#      'cc': 'US',
#      'city': 'Alpharetta',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['10795 Davis Dr',
#       'Alpharetta, GA 30009',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ce941735',
#       'name': 'Seafood Restaurant',
#       'pluralName': 'Seafood Restaurants',
#       'shortName': 'Seafood',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1469268',
#      'url': 'https://www.grubhub.com/restaurant/pappadeaux-seafood-kitchen-557-10795-davis-drive-alpharetta/1469268?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1469268',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1582412373',
#     'hasPerk': False},
#    {'id': '4afa19b3f964a520bc1622e3',
#     'name': 'Atlantic Seafood Co.',
#     'location': {'address': '2345 Mansell Rd',
#      'lat': 34.03734037323762,
#      'lng': -84.30705237234183,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.03734037323762,
#        'lng': -84.30705237234183}],
#      'distance': 5252,
#      'postalCode': '30022',
#      'cc': 'US',
#      'city': 'Alpharetta',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['2345 Mansell Rd',
#       'Alpharetta, GA 30022',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ce941735',
#       'name': 'Seafood Restaurant',
#       'pluralName': 'Seafood Restaurants',
#       'shortName': 'Seafood',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1468944',
#      'url': 'https://www.grubhub.com/restaurant/atlantic-seafood-company-2345-mansell-road-alpharetta/1468944?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1468944',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'venuePage': {'id': '58866912'},
#     'referralId': 'v-1582412373',
#     'hasPerk': False},
#    {'id': '4f32617219836c91c7d22a44',
#     'name': "Crabby Bill's Seafood Restaurant",
#     'location': {'address': '10730 Alpharetta Hwy',
#      'lat': 34.049831,
#      'lng': -84.337798,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.049831,
#        'lng': -84.337798}],
#      'distance': 2101,
#      'postalCode': '30076',
#      'cc': 'US',
#      'city': 'Roswell',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['10730 Alpharetta Hwy',
#       'Roswell, GA 30076',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ce941735',
#       'name': 'Seafood Restaurant',
#       'pluralName': 'Seafood Restaurants',
#       'shortName': 'Seafood',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582412373',
#     'hasPerk': False},
#    {'id': '4f32a43619836c91c7eb8c38',
#     'name': 'Captain Ds Seafood',
#     'location': {'address': '419 E Crossville Rd',
#      'lat': 34.039227,
#      'lng': -84.349683,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.039227,
#        'lng': -84.349683}],
#      'distance': 2408,
#      'postalCode': '30075',
#      'cc': 'US',
#      'city': 'Roswell',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['419 E Crossville Rd',
#       'Roswell, GA 30075',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ce941735',
#       'name': 'Seafood Restaurant',
#       'pluralName': 'Seafood Restaurants',
#       'shortName': 'Seafood',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582412373',
#     'hasPerk': False},
#    {'id': '5c96c4dd123a19002c4e0ebd',
#     'name': 'Lapeer Seafood Market',
#     'location': {'address': '12 N Broad St',
#      'lat': 34.074912,
#      'lng': -84.294031,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.074912,
#        'lng': -84.294031}],
#      'distance': 6039,
#      'postalCode': '30009',
#      'cc': 'US',
#      'city': 'Alpharetta',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['12 N Broad St',
#       'Alpharetta, GA 30009',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ce941735',
#       'name': 'Seafood Restaurant',
#       'pluralName': 'Seafood Restaurants',
#       'shortName': 'Seafood',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1469189',
#      'url': 'https://www.grubhub.com/restaurant/lapeer-seafood-market-12-north-broad-street-alpharetta/1469189?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1469189',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1582412373',
#     'hasPerk': False},
#    {'id': '5221291511d28fe392741a2d',
#     'name': 'Atlatic Seafood Company',
#     'location': {'lat': 34.04586486472025,
#      'lng': -84.3041485125057,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.04586486472025,
#        'lng': -84.3041485125057}],
#      'distance': 5122,
#      'cc': 'US',
#      'city': 'Alpharetta',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['Alpharetta, GA', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ce941735',
#       'name': 'Seafood Restaurant',
#       'pluralName': 'Seafood Restaurants',
#       'shortName': 'Seafood',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582412373',
#     'hasPerk': False},
#    {'id': '4bc3a2d2920eb713ddc21d2c',
#     'name': "Captain D's",
#     'location': {'address': '705 Holcomb Bridge Rd',
#      'crossStreet': 'Old Roswell Rd.',
#      'lat': 34.03165634439797,
#      'lng': -84.3403016030789,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.03165634439797,
#        'lng': -84.3403016030789}],
#      'distance': 3511,
#      'postalCode': '30076',
#      'cc': 'US',
#      'city': 'Roswell',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['705 Holcomb Bridge Rd (Old Roswell Rd.)',
#       'Roswell, GA 30076',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ce941735',
#       'name': 'Seafood Restaurant',
#       'pluralName': 'Seafood Restaurants',
#       'shortName': 'Seafood',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '822988',
#      'url': 'https://www.grubhub.com/restaurant/captain-ds-705-holcomb-bridge-rd-roswell/822988?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=822988',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1582412373',
#     'hasPerk': False},
#    {'id': '58f1136793bd634eff82c2ed',
#     'name': 'Brine Seafood Shack',
#     'location': {'address': '700 Avalon Blvd',
#      'lat': 34.070711323890976,
#      'lng': -84.27447615951422,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.070711323890976,
#        'lng': -84.27447615951422}],
#      'distance': 7702,
#      'postalCode': '30009',
#      'cc': 'US',
#      'city': 'Alpharetta',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['700 Avalon Blvd',
#       'Alpharetta, GA 30009',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ce941735',
#       'name': 'Seafood Restaurant',
#       'pluralName': 'Seafood Restaurants',
#       'shortName': 'Seafood',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582412373',
#     'hasPerk': False},
#    {'id': '59ebbc689de23b0d2d44bf46',
#     'name': 'Wings & Seafood',
#     'location': {'address': 'Roswell Road',
#      'lat': 33.982753,
#      'lng': -84.348746,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.982753,
#        'lng': -84.348746}],
#      'distance': 8632,
#      'postalCode': '30350',
#      'cc': 'US',
#      'city': 'Sandy Springs',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['Roswell Road',
#       'Sandy Springs, GA 30350',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1466787',
#      'url': 'https://www.grubhub.com/restaurant/wings-and-seafood-8339-roswell-road-sandy-springs/1466787?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1466787',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1582412373',
#     'hasPerk': False},
#    {'id': '4b2d6a96f964a52038d624e3',
#     'name': "Chicago's",
#     'location': {'address': '4401 Shallowford Rd',
#      'lat': 34.0276574,
#      'lng': -84.423039,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.0276574,
#        'lng': -84.423039}],
#      'distance': 7075,
#      'postalCode': '30075',
#      'cc': 'US',
#      'city': 'Roswell',
#      'state': 'GA',
#      'country': 'United States',
#      'formattedAddress': ['4401 Shallowford Rd',
#       'Roswell, GA 30075',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1498660',
#      'url': 'https://www.grubhub.com/restaurant/chicagos-restaurant-4401-shallowford-road-roswell/1498660?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1498660',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1582412373',
#     'hasPerk': False}]}}

# %%
venues = results['response']['venues']

dataframe = json_normalize(venues)
dataframe.head(10)
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...     1469268
# 1  [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...     1468944
# 2  [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...         NaN
# 3  [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...         NaN
# 4  [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...     1469189
# 5  [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...         NaN
# 6  [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...      822988
# 7  [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...         NaN
# 8  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...     1466787
# 9  [{'id': '4bf58dd8d48988d1cc941735', 'name': 'S...     1498660
#
#                delivery.provider.icon.name  \
# 0  /delivery_provider_grubhub_20180129.png
# 1  /delivery_provider_grubhub_20180129.png
# 2                                      NaN
# 3                                      NaN
# 4  /delivery_provider_grubhub_20180129.png
# 5                                      NaN
# 6  /delivery_provider_grubhub_20180129.png
# 7                                      NaN
# 8  /delivery_provider_grubhub_20180129.png
# 9  /delivery_provider_grubhub_20180129.png
#
#               delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 1  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 2                                       NaN                          NaN
# 3                                       NaN                          NaN
# 4  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 5                                       NaN                          NaN
# 6  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 7                                       NaN                          NaN
# 8  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 9  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
#
#   delivery.provider.name                                       delivery.url  \
# 0                grubhub  https://www.grubhub.com/restaurant/pappadeaux-...
# 1                grubhub  https://www.grubhub.com/restaurant/atlantic-se...
# 2                    NaN                                                NaN
# 3                    NaN                                                NaN
# 4                grubhub  https://www.grubhub.com/restaurant/lapeer-seaf...
# 5                    NaN                                                NaN
# 6                grubhub  https://www.grubhub.com/restaurant/captain-ds-...
# 7                    NaN                                                NaN
# 8                grubhub  https://www.grubhub.com/restaurant/wings-and-s...
# 9                grubhub  https://www.grubhub.com/restaurant/chicagos-re...
#
#    hasPerk                        id       location.address  ...  \
# 0    False  4a8864b0f964a520310620e3         10795 Davis Dr  ...
# 1    False  4afa19b3f964a520bc1622e3        2345 Mansell Rd  ...
# 2    False  4f32617219836c91c7d22a44   10730 Alpharetta Hwy  ...
# 3    False  4f32a43619836c91c7eb8c38    419 E Crossville Rd  ...
# 4    False  5c96c4dd123a19002c4e0ebd          12 N Broad St  ...
# 5    False  5221291511d28fe392741a2d                    NaN  ...
# 6    False  4bc3a2d2920eb713ddc21d2c  705 Holcomb Bridge Rd  ...
# 7    False  58f1136793bd634eff82c2ed        700 Avalon Blvd  ...
# 8    False  59ebbc689de23b0d2d44bf46           Roswell Road  ...
# 9    False  4b2d6a96f964a52038d624e3    4401 Shallowford Rd  ...
#
#   location.distance                          location.formattedAddress  \
# 0              4655  [10795 Davis Dr, Alpharetta, GA 30009, United ...
# 1              5252  [2345 Mansell Rd, Alpharetta, GA 30022, United...
# 2              2101  [10730 Alpharetta Hwy, Roswell, GA 30076, Unit...
# 3              2408  [419 E Crossville Rd, Roswell, GA 30075, Unite...
# 4              6039  [12 N Broad St, Alpharetta, GA 30009, United S...
# 5              5122                    [Alpharetta, GA, United States]
# 6              3511  [705 Holcomb Bridge Rd (Old Roswell Rd.), Rosw...
# 7              7702  [700 Avalon Blvd, Alpharetta, GA 30009, United...
# 8              8632  [Roswell Road, Sandy Springs, GA 30350, United...
# 9              7075  [4401 Shallowford Rd, Roswell, GA 30075, Unite...
#
#                              location.labeledLatLngs location.lat  \
# 0  [{'label': 'display', 'lat': 34.04173, 'lng': ...    34.041730
# 1  [{'label': 'display', 'lat': 34.03734037323762...    34.037340
# 2  [{'label': 'display', 'lat': 34.049831, 'lng':...    34.049831
# 3  [{'label': 'display', 'lat': 34.039227, 'lng':...    34.039227
# 4  [{'label': 'display', 'lat': 34.074912, 'lng':...    34.074912
# 5  [{'label': 'display', 'lat': 34.04586486472025...    34.045865
# 6  [{'label': 'display', 'lat': 34.03165634439797...    34.031656
# 7  [{'label': 'display', 'lat': 34.07071132389097...    34.070711
# 8  [{'label': 'display', 'lat': 33.982753, 'lng':...    33.982753
# 9  [{'label': 'display', 'lat': 34.0276574, 'lng'...    34.027657
#
#    location.lng location.postalCode location.state  \
# 0    -84.311590               30009             GA
# 1    -84.307052               30022             GA
# 2    -84.337798               30076             GA
# 3    -84.349683               30075             GA
# 4    -84.294031               30009             GA
# 5    -84.304149                 NaN             GA
# 6    -84.340302               30076             GA
# 7    -84.274476               30009             GA
# 8    -84.348746               30350             GA
# 9    -84.423039               30075             GA
#
#                                name    referralId venuePage.id
# 0        Pappadeaux Seafood Kitchen  v-1582412373          NaN
# 1              Atlantic Seafood Co.  v-1582412373     58866912
# 2  Crabby Bill's Seafood Restaurant  v-1582412373          NaN
# 3                Captain Ds Seafood  v-1582412373          NaN
# 4             Lapeer Seafood Market  v-1582412373          NaN
# 5           Atlatic Seafood Company  v-1582412373          NaN
# 6                       Captain D's  v-1582412373          NaN
# 7               Brine Seafood Shack  v-1582412373          NaN
# 8                   Wings & Seafood  v-1582412373          NaN
# 9                         Chicago's  v-1582412373          NaN
#
# [10 rows x 24 columns]

# %%
venues = results['response']['venues']

dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...     1469268
# 1  [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...     1468944
# 2  [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...         NaN
# 3  [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...         NaN
# 4  [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...     1469189
#
#                delivery.provider.icon.name  \
# 0  /delivery_provider_grubhub_20180129.png
# 1  /delivery_provider_grubhub_20180129.png
# 2                                      NaN
# 3                                      NaN
# 4  /delivery_provider_grubhub_20180129.png
#
#               delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 1  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 2                                       NaN                          NaN
# 3                                       NaN                          NaN
# 4  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
#
#   delivery.provider.name                                       delivery.url  \
# 0                grubhub  https://www.grubhub.com/restaurant/pappadeaux-...
# 1                grubhub  https://www.grubhub.com/restaurant/atlantic-se...
# 2                    NaN                                                NaN
# 3                    NaN                                                NaN
# 4                grubhub  https://www.grubhub.com/restaurant/lapeer-seaf...
#
#    hasPerk                        id      location.address  ...  \
# 0    False  4a8864b0f964a520310620e3        10795 Davis Dr  ...
# 1    False  4afa19b3f964a520bc1622e3       2345 Mansell Rd  ...
# 2    False  4f32617219836c91c7d22a44  10730 Alpharetta Hwy  ...
# 3    False  4f32a43619836c91c7eb8c38   419 E Crossville Rd  ...
# 4    False  5c96c4dd123a19002c4e0ebd         12 N Broad St  ...
#
#   location.distance                          location.formattedAddress  \
# 0              4655  [10795 Davis Dr, Alpharetta, GA 30009, United ...
# 1              5252  [2345 Mansell Rd, Alpharetta, GA 30022, United...
# 2              2101  [10730 Alpharetta Hwy, Roswell, GA 30076, Unit...
# 3              2408  [419 E Crossville Rd, Roswell, GA 30075, Unite...
# 4              6039  [12 N Broad St, Alpharetta, GA 30009, United S...
#
#                              location.labeledLatLngs location.lat  \
# 0  [{'label': 'display', 'lat': 34.04173, 'lng': ...    34.041730
# 1  [{'label': 'display', 'lat': 34.03734037323762...    34.037340
# 2  [{'label': 'display', 'lat': 34.049831, 'lng':...    34.049831
# 3  [{'label': 'display', 'lat': 34.039227, 'lng':...    34.039227
# 4  [{'label': 'display', 'lat': 34.074912, 'lng':...    34.074912
#
#    location.lng location.postalCode location.state  \
# 0    -84.311590               30009             GA
# 1    -84.307052               30022             GA
# 2    -84.337798               30076             GA
# 3    -84.349683               30075             GA
# 4    -84.294031               30009             GA
#
#                                name    referralId venuePage.id
# 0        Pappadeaux Seafood Kitchen  v-1582412373          NaN
# 1              Atlantic Seafood Co.  v-1582412373     58866912
# 2  Crabby Bill's Seafood Restaurant  v-1582412373          NaN
# 3                Captain Ds Seafood  v-1582412373          NaN
# 4             Lapeer Seafood Market  v-1582412373          NaN
#
# [5 rows x 24 columns]

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                name          categories  \
# 0        Pappadeaux Seafood Kitchen  Seafood Restaurant
# 1              Atlantic Seafood Co.  Seafood Restaurant
# 2  Crabby Bill's Seafood Restaurant  Seafood Restaurant
# 3                Captain Ds Seafood  Seafood Restaurant
# 4             Lapeer Seafood Market  Seafood Restaurant
# 5           Atlatic Seafood Company  Seafood Restaurant
# 6                       Captain D's  Seafood Restaurant
# 7               Brine Seafood Shack  Seafood Restaurant
# 8                   Wings & Seafood          Restaurant
# 9                         Chicago's          Steakhouse
#
#                  address  cc           city        country      crossStreet  \
# 0         10795 Davis Dr  US     Alpharetta  United States              NaN
# 1        2345 Mansell Rd  US     Alpharetta  United States              NaN
# 2   10730 Alpharetta Hwy  US        Roswell  United States              NaN
# 3    419 E Crossville Rd  US        Roswell  United States              NaN
# 4          12 N Broad St  US     Alpharetta  United States              NaN
# 5                    NaN  US     Alpharetta  United States              NaN
# 6  705 Holcomb Bridge Rd  US        Roswell  United States  Old Roswell Rd.
# 7        700 Avalon Blvd  US     Alpharetta  United States              NaN
# 8           Roswell Road  US  Sandy Springs  United States              NaN
# 9    4401 Shallowford Rd  US        Roswell  United States              NaN
#
#    distance                                   formattedAddress  \
# 0      4655  [10795 Davis Dr, Alpharetta, GA 30009, United ...
# 1      5252  [2345 Mansell Rd, Alpharetta, GA 30022, United...
# 2      2101  [10730 Alpharetta Hwy, Roswell, GA 30076, Unit...
# 3      2408  [419 E Crossville Rd, Roswell, GA 30075, Unite...
# 4      6039  [12 N Broad St, Alpharetta, GA 30009, United S...
# 5      5122                    [Alpharetta, GA, United States]
# 6      3511  [705 Holcomb Bridge Rd (Old Roswell Rd.), Rosw...
# 7      7702  [700 Avalon Blvd, Alpharetta, GA 30009, United...
# 8      8632  [Roswell Road, Sandy Springs, GA 30350, United...
# 9      7075  [4401 Shallowford Rd, Roswell, GA 30075, Unite...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 34.04173, 'lng': ...  34.041730 -84.311590
# 1  [{'label': 'display', 'lat': 34.03734037323762...  34.037340 -84.307052
# 2  [{'label': 'display', 'lat': 34.049831, 'lng':...  34.049831 -84.337798
# 3  [{'label': 'display', 'lat': 34.039227, 'lng':...  34.039227 -84.349683
# 4  [{'label': 'display', 'lat': 34.074912, 'lng':...  34.074912 -84.294031
# 5  [{'label': 'display', 'lat': 34.04586486472025...  34.045865 -84.304149
# 6  [{'label': 'display', 'lat': 34.03165634439797...  34.031656 -84.340302
# 7  [{'label': 'display', 'lat': 34.07071132389097...  34.070711 -84.274476
# 8  [{'label': 'display', 'lat': 33.982753, 'lng':...  33.982753 -84.348746
# 9  [{'label': 'display', 'lat': 34.0276574, 'lng'...  34.027657 -84.423039
#
#   postalCode state                        id
# 0      30009    GA  4a8864b0f964a520310620e3
# 1      30022    GA  4afa19b3f964a520bc1622e3
# 2      30076    GA  4f32617219836c91c7d22a44
# 3      30075    GA  4f32a43619836c91c7eb8c38
# 4      30009    GA  5c96c4dd123a19002c4e0ebd
# 5        NaN    GA  5221291511d28fe392741a2d
# 6      30076    GA  4bc3a2d2920eb713ddc21d2c
# 7      30009    GA  58f1136793bd634eff82c2ed
# 8      30350    GA  59ebbc689de23b0d2d44bf46
# 9      30075    GA  4b2d6a96f964a52038d624e3

# %%
dataframe_filtered.name
# Out:
# 0          Pappadeaux Seafood Kitchen
# 1                Atlantic Seafood Co.
# 2    Crabby Bill's Seafood Restaurant
# 3                  Captain Ds Seafood
# 4               Lapeer Seafood Market
# 5             Atlatic Seafood Company
# 6                         Captain D's
# 7                 Brine Seafood Shack
# 8                     Wings & Seafood
# 9                           Chicago's
# Name: name, dtype: object
